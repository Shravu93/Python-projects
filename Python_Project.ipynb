# %%
pip install pandas

# %%
pip install seaborn

# %%
pip install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Diwali Sales Data.csv", encoding='latin-1')

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
# drop blank columns

df.drop(["Status","unnamed1"], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# drop null values

df.shape
# Out:
# (11251, 13)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (11239, 13)

# %%
# data type change

df["Amount"]= df["Amount"].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns={'Gender':'Sex'})
# Out:
#        User_ID    Cust_name Product_ID Sex Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942   F     26-35   28               0
# 1      1000732       Kartik  P00110942   F     26-35   35               1
# 2      1001990        Bindu  P00118542   F     26-35   35               1
# 3      1001425       Sudevi  P00237842   M      0-17   16               0
# 4      1000588         Joni  P00057942   M     26-35   28               1
# ...        ...          ...        ...  ..       ...  ...             ...
# 11246  1000695      Manning  P00296942   M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342   M     26-35   33               0
# 11248  1001209        Oshin  P00201342   F     36-45   40               0
# 11249  1004023       Noonan  P00059442   M     36-45   37               0
# 11250  1002744      Brumley  P00281742   F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
# Use describe()
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Age'], **{})
# chart
# ...

# %% [markdown]
# ## Exploratory Data **Analysis**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax = sns.countplot(x = 'Gender', data = df)

for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_gen = df.groupby(['Gender'])['Amount'].sum().reset_index()

# %%
sales_gen
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
sns.barplot(x = 'Gender', y = 'Amount', data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# # from Above graphs we can see that most of the buyers are females

# %% [markdown]
# # Age

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax = sns.countplot( data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
  ax.bar_label(bars)

# %%
# Total Amount vs Age Group

sales_age = df.groupby(['Age Group'])['Amount'].sum().reset_index()

# %%
sales_age
# Out:
#   Age Group    Amount
# 0      0-17   2699653
# 1     18-25  17240732
# 2     26-35  42613442
# 3     36-45  22144994
# 4     46-50   9207844
# 5     51-55   8261477
# 6       55+   4080987

# %%
sns.barplot(x = 'Age Group', y = 'Amount', data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# # **From this graphs we can see that most of the buyers are of age group between 26-35 years**

# %% [markdown]
# # Sates

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sales_state = df.groupby(['State'])['Orders'].sum().reset_index().head(10)

# %%
sales_state
# Out:
#               State  Orders
# 0    Andhra Pradesh    2051
# 1             Bihar    1062
# 2             Delhi    2740
# 3           Gujarat    1066
# 4           Haryana    1109
# 5  Himachal Pradesh    1568
# 6         Jharkhand     953
# 7         Karnataka    3240
# 8            Kerala    1137
# 9    Madhya Pradesh    2252

# %%
sns.set(rc={'figure.figsize': (15,5)})

# %%
sns.barplot(data =sales_state, x = "State", y = "Orders" )
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
sales_state = df.groupby(['State'])['Amount'].sum().reset_index().head(10)

# %%
sales_state
# Out:
#               State    Amount
# 0    Andhra Pradesh   8037146
# 1             Bihar   4022757
# 2             Delhi  11603818
# 3           Gujarat   3946082
# 4           Haryana   4220175
# 5  Himachal Pradesh   4963368
# 6         Jharkhand   3026456
# 7         Karnataka  13523540
# 8            Kerala   3894491
# 9    Madhya Pradesh   8101142

# %%
sns.set(rc={'figure.figsize': (15,5)})

# %%
sns.barplot(data =sales_state, x = "State", y = "Amount" )
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# # From above graphs we can see that most of the orders and total sales amount are from Karnataka.

# %% [markdown]
# # Marital Status

# %%
sns.set(rc ={'figure.figsize':(5,5)})

# %%
ax = sns.countplot( x = "Marital_Status", data = df)

for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_age = df.groupby(["Marital_Status",'Gender'])["Amount"].sum().reset_index()

# %%
sales_age
# Out:
#    Marital_Status Gender    Amount
# 0               0      F  43786646
# 1               0      M  18338738
# 2               1      F  30549207
# 3               1      M  13574538

# %%
sns.barplot(x = "Marital_Status", y = 'Amount', hue = 'Gender', data = sales_age)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# # From above graphs we can see that most of the buyers are married (female) & they have high purchasing power.

# %% [markdown]
# # Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})

# %%
ax = sns.countplot(x = 'Occupation', data = df )

for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'])['Amount'].sum().reset_index()

# %%
sales_state
# Out:
#          Occupation    Amount
# 0       Agriculture   2593087
# 1        Automobile   5368596
# 2          Aviation  12602298
# 3           Banking  10770610
# 4          Chemical   5297436
# 5      Construction   3597511
# 6   Food Processing   4070670
# 7              Govt   8517212
# 8        Healthcare  13034586
# 9       Hospitality   6376405
# 10        IT Sector  14755079
# 11           Lawyer   4981665
# 12            Media   6295832
# 13           Retail   4783170
# 14          Textile   3204972

# %%
sns.set(rc={'figure.figsize': (20,5)})
sns.barplot(x ='Occupation', y = "Amount", data =sales_state )
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# # From above graphs we can see that most of the buyers are working in IT sector and also having more purchasing power.

# %% [markdown]
# # Product categories

# %%
sns.set(rc={'figure.figsize': (27,7)})
ax = sns.countplot(x ='Product_Category', data =df )

for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_state = df.groupby(['Product_Category'])['Amount'].sum().reset_index()

# %%
sales_state
# Out:
#          Product_Category    Amount
# 0                    Auto   1958609
# 1                  Beauty   1959484
# 2                   Books   1061478
# 3      Clothing & Apparel  16495019
# 4                   Decor    730360
# 5   Electronics & Gadgets  15643846
# 6                    Food  33933883
# 7        Footwear & Shoes  15575209
# 8               Furniture   5440051
# 9            Games & Toys   4331694
# 10     Hand & Power Tools    405618
# 11        Household items   1569337
# 12                 Office     81936
# 13               Pet Care    482277
# 14        Sports Products   3635933
# 15             Stationery   1676051
# 16             Tupperware   1155642
# 17             Veterinary    112702

# %%
sns.set(rc={'figure.figsize': (27,7)})
sns.barplot(x ='Product_Category', y = 'Amount', data = sales_state)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# # From above graphs we can see that most of sold products are clothing & Apparel, Food and Electronics gadgets

# %% [markdown]
# # Conclusion:

# %% [markdown]
# Married females age group 26-35 years from Karnataka working in IT are more likely to buy products from clothing Apparel, Food & Electronics Gadgets.
